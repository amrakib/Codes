# %% [markdown]
# ###***Class Task***

# %% [markdown]
# ***Class Task 1: Playing With Datatypes and Inputs***

# %%
#task 1.1
message=input()
numbers=int(input())
print(message)
print(numbers)
# Out:
# hello world
# 21
# hello world
# 21

# %%
#task 1.2
num1=int(input())
num2=int(input())
print("Summation:",num1+num2)
print("Multiplication:",num1*num2)
# Out:
# 10
# 5
# Summation: 15
# Multiplication: 50

# %%
#task 1.3
digit=int(input())
decimal=float(input())
print(digit+decimal,digit-decimal)
# Out:
# 4
# 5
# 9.0 -1.0

# %%
#task 1.4
num1=int(input())
num2=int(input())
decimal=float(num2)
num3=str(num1)
num4=str(decimal)
print(num3+num4)
# Out:
# 2
# 3
# 23.0

# %% [markdown]
# ***Class Task 2: Playing With Operators***

# %%
#task 2
M=int(input())
N=int(input())
calc=M**N
print(f"{M}^{N}: {calc}")
# Out:
# 2
# 3
# 2^3: 8

# %% [markdown]
# ***Class Task 3: Calculating Maximum Weight***

# %%
#task 3
weight=int(input())
goods=weight//4
print(goods*4)
# Out:
# 11
# 8

# %% [markdown]
# ###***Class Evaluation Task***

# %% [markdown]
# ***Class Evaluation Task 1: Operator Precedence***

# %%
#task 1
A=int(input())
B=int(input())
C=int(input())
D=float(input())
formula=A**C+(2*B)*(A//2)-D/3
print(int(formula))
# Out:
# 88
# 22
# 1
# 3.3
# 2022

# %% [markdown]
# ***Class Evaluation Task 2:***

# %%
#task 2
firstname=input("Enter First Name: ")
lastname=input("Enter Last Name: ")
age=int(input("Enter Age: "))
cgpa=float(input("Enter CGPA: "))
lastname="Rahman"
age=age-2
cgpa=cgpa+0.25
print("Name:",firstname,lastname)
print("Age:",age)
print("CGPA:",cgpa)
# Out:
# Enter First Name: Ron1n
# Enter Last Name: Gandu
# Enter Age: 23
# Enter CGPA: 2.8
# Name: Ron1n Rahman
# Age: 21
# CGPA: 3.05

# %% [markdown]
# ###***Home Task***

# %% [markdown]
# ***Home Task 3: Chocolate Dilemma***

# %%
#hometask 3
chocolate=int(input("No. of Chocolates: "))
friends=chocolate//3
user=chocolate-(friends*3)
print(f"Each friend will receive {friends} chocolates")
print(f"The number of remaining chocolates is {user}")
# Out:
# No. of Chocolates: 50
# Each friend will receive 16 chocolates
# The number of remaining chocolates is 2
