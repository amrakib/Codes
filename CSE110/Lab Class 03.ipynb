# %% [markdown]
# ###***Class Task***

# %% [markdown]
# ***Class Task 1***

# %%
#Class Task 1 (While Loop)
num = 18
while num <= 63:
  if num == 63:
    print(num, end="" )
  else:
    print(num, end=",")
  num += 9

print() #This Line is to Separate the Code

#Class Task 1 (For Loop)
for i in range(18,64,9):
  if i == 63:
    print(i, end="")
  else:
    print(i, end=",")
# Out:
# 18,27,36,45,54,63
# 18,27,36,45,54,63

# %% [markdown]
# ***Class Task 2***

# %%
#Class Task 2
num = int(input())
sum = 0
for i in range(1, num+1):
  if i % 2 != 0:
    sum += i**2
  else:
    sum -= i**2
print(sum)
# Out:
# 20
# -210

# %% [markdown]
# ***Class Task 3***

# %%
#Class Task 3
num = int(input())
while num > 0:
  if 0 <= num <= 9:
     print(num)
  else:
     print(num%10, end=", ")
  num //= 10
# Out:
# 31775
# 5, 7, 7, 1, 3

# %% [markdown]
# ***Class Task 4***

# %%
#Class Task 4
num = int(input())
counter = 0
for i in range(1, num+1):
  if num % i == 0:
    print(i)
    counter += 1
print(f"Total {counter} divisors.")
# Out:
# 121
# 1
# 11
# 121
# Total 3 divisors.

# %% [markdown]
# ***Class Task 5***

# %%
#Class Task 5
row = int(input())
column = int(input())
for r in range(row):
  for c in range(1, column+1):
    print(c, end="")
  print()
# Out:
# 4
# 6
# 123456
# 123456
# 123456
# 123456

# %% [markdown]
# ###***Evaluation Task***

# %% [markdown]
# ***Class Evaluation Task 1***

# %%
#Class Evaluation Task 1
for i in range(18, 64, 9):
  if i%2 == 0:
    print(i, end=", ")
  elif i == 63:
      print(-i)
  else:
      print(-i, end=", ")
# Out:
# 18, -27, 36, -45, 54, -63

# %% [markdown]
# ***Class Evaluation Task 2***

# %%
n = 1
for i in range(5):
  num = int(input())
  n *= num
  print(n)
# Out:
# -10
# -10
# -2
# 20
# 3
# 60
# 2
# 120
# -1
# -120

# %% [markdown]
# ###***Home Task***

# %% [markdown]
# ***Home Task 1***

# %%
# Home Task 1
numeral = int(input())
sum = 0
for i in range(1, numeral+1):
    if i % 7 == 0 or i % 9 == 0:
        sum += i
    if i % 7 == 0 and i % 9 == 0:
        sum -= i
print(sum)
# Out:
# 75
# 583

# %% [markdown]
# ***Home Task 2***

# %%
# Home Task 2
user_input = int(input())
numeral = user_input
counter = 0
while user_input != 0:
    user_input //= 10
    counter += 1
import math
divisor = int(math.pow(10,(counter - 1)))
for i in range(1, counter+1):
    number = numeral // divisor
    numeral %= divisor
    divisor //= 10
    if i < counter:
        print(number, end=",")
    else:
        print(number)
# Out:
# 32768
# 3,2,7,6,8

# %% [markdown]
# ***Home Task 3***

# %%
# Home Task 3
numeral = int(input())
sum = 0
counter = 0
for i in range(1, numeral+1):
    if numeral % i == 0:
        counter += 1
        if i < numeral:
            sum += i
if counter == 2:
    print(f"{numeral} is a prime number")
elif numeral == sum:
    print(f"{numeral} is a perfect number")
else:
    print(f"{numeral} is not a prime or perfect number")
# Out:
# 7
# 7 is a prime number

# %% [markdown]
# ***Home Task 4***

# %%
# Home Task 4
import math
quantity = int(input())
sum = 0
min = +math.inf
max = -math.inf
for i in range(quantity):
    x = int(input())
    if x > max:
        max = x
    if x < min:
        min = x
    sum += x
print(f"""Maximum {max}
Minimun {min}
Average {sum/quantity}""")
# Out:
# 5
# 10
# 4
# -1
# -100
# 1
# Maximum 10
# Minimun -100
# Average -17.2

# %% [markdown]
# ***Home Task 5***

# %%
# Home Task 5
numeral = int(input())
for r in range(1, numeral+1):
    for c in range(1, r+1):
        print(c, end="")
    print()
# Out:
# 5
# 1
# 12
# 123
# 1234
# 12345

# %% [markdown]
# ***Home Task 6 (Tracing)***

# %%
# Home Task 6 (Tracing)
x = 0
y = 0
q = 0
sum = 0
while (x < 10):
    p = 0.0
    p = x + y - sum + int(5 / 3) / 3.0 % 2 ** 3
    y = x // 5
    while (y < x):
        q = (x + 10.0) / 2
        sum = (sum % 2) + y + int(p)
        print(sum)
        y = y + 4
    if (x > 5):
        x += 3
    else:
        x += 2
        print(int(p) + q)
print(sum - q)
# Out:
# 0
# 2
# 8.0
# 6
# 13.0
# 5
# 10
# 9
# 14
# 4.5

# %% [markdown]
# ***Home Task 7 (Tracing)***

# %%
#Home Task 7 (Tracing)
test = 1
j = 0
k = 100
while (k > 0):
    while (j < k):
        test += k + j - 21
        print(1 + int(test / 2))
        j += 10
    k -= 10
    test = 1
# Out:
# 41
# 85
# 135
# 189
# 249
# 313
# 383
# 457
# 537
# 621

# %% [markdown]
# ***Home Task 8 (Tracing)***

# %%
#Home Task 7 (Tracing)
p = 0
r = 0
while p < 7:
    q = 1
    while q <= p:
        q = q + 1
        if q == 4 or q == 5:
            continue
            print(p - q * 2)
        elif p == 6:
            break
            print(p % q)
        else:
            r = p * q - int(21 / q)
            print(r)
    p = p + 1
# Out:
# -8
# -6
# -1
# -4
# 2
# -2
# 5
# 0
# 8
# 27
